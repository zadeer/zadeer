# %% [markdown]
# <a href="https://colab.research.google.com/github/zadeer/zadeer/blob/main/summary_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import data
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7e2987dd-6e12-4537-babf-e476f39112eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e2987dd-6e12-4537-babf-e476f39112eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#import libriries
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
from io import BytesIO

data = pd.read_csv(BytesIO(uploaded['test.csv']))
data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
data['Age'].fillna(data['Age'].median(), inplace=True)
data.dropna(subset=['Fare'], inplace=True)
data.drop(columns=['Cabin'], inplace=True)
data.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#identify outliers by using boxplot
data['PassengerId'].value_counts().plot(kind='box')
plt.show()
data['Pclass'].value_counts().plot(kind='box')
plt.show()
data['Sex'].value_counts().plot(kind='box')
plt.show()
data['Age'].value_counts().plot(kind='box')
plt.show()
data['Name'].value_counts().plot(kind='box')
plt.show()
data['SibSp'].value_counts().plot(kind='box')
plt.show()
data['Parch'].value_counts().plot(kind='box')
plt.show()
data['Ticket'].value_counts().plot(kind='box')
plt.show()
data['Fare'].value_counts().plot(kind='box')
plt.show()
data['Embarked'].value_counts().plot(kind='box')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# Box plots for numerical variables
data[['Age', 'Fare', 'SibSp', 'Parch']].plot(kind='box', subplots=True, layout=(2, 2), figsize=(10, 8))
plt.show()

Q1 = data['Fare'].quantile(0.25)
Q3 = data['Fare'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3+7.5 * IQR

# %%
data = data[(data['Fare'] >= lower_bound) & (data['Fare'] <= upper_bound)]
data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
#import data
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-bf1c0a28-a0a8-4e2e-aa5b-217fe695d1ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf1c0a28-a0a8-4e2e-aa5b-217fe695d1ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from io import BytesIO

# %%
data1 = pd.read_csv(BytesIO(uploaded['train.csv']))
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#identify nullvalues
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data1['Age'].fillna(data1['Age'].median(), inplace=True)
data1.dropna(subset=['Fare'], inplace=True)

# %%
data1['Age'].fillna(data1['Age'].median(), inplace=True)
data1.dropna(subset=['Fare'], inplace=True)

# %%
# Check if 'Cabin' column exists before dropping it
if 'Cabin' in data1.columns:
    data1.drop(columns=['Cabin'], inplace=True)

# %%
# Check for any remaining null values
data1.isnull().sum()
# Fill missing values in the 'Embarked' column with the mode
data1['Embarked'].fillna(data1['Embarked'].mode()[0], inplace=True)

# %%
# Check if there are any remaining null values
data1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define numerical and categorical attributes
numerical_attributes = ['Age', 'SibSp', 'Parch', 'Fare']
categorical_attributes = ['Pclass', 'Sex', 'Embarked']

# %%
# Plot box plots for numerical attributes
for attribute in numerical_attributes:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=data1[attribute])

    plt.show()

# %%
# Plot count plots for categorical attributes
for attribute in categorical_attributes:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=data1[attribute])

    plt.show()

# %%
# Plot count plots for categorical attributes
for attribute in categorical_attributes:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=data1[attribute])

    plt.show()

# %%
#removing outliers using IQR method
Q11=data1['Fare'].quantile(0.25)
Q31=data['Fare'].quantile(0.75)
IQR1=Q31-Q11
lower_bound1=Q11-1.5*IQR1
UPPER_BOUND1=Q31-7.5*IQR1
data1[(data1['Fare']>=lower_bound)& (data1['Fare']<=UPPER_BOUND1)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []
